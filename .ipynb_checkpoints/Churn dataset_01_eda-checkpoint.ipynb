# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Explore Churn Dataset**

# %%
churn_df = pd.read_csv("/Users/estelle90/Downloads/ChurnAnalysisProject/archive 2/churn-data.csv")
churn_df.head()
# Out:
#    Unnamed: 0 Churn gender  SeniorCitizen Partner Dependents  tenure  \
# 0        3000   Yes   Male              0      No         No      12
# 1        3001    No   Male              0      No         No       9
# 2        3002    No   Male              0      No         No      27
# 3        3003   Yes   Male              0      No        Yes      27
# 4        3004   Yes   Male              0     Yes        Yes       1
#
#   PhoneService MultipleLines InternetService  ...     DeviceProtection  \
# 0          Yes           Yes     Fiber optic  ...                   No
# 1          Yes            No              No  ...  No internet service
# 2          Yes            No             DSL  ...                  Yes
# 3          Yes           Yes     Fiber optic  ...                   No
# 4          Yes            No     Fiber optic  ...                   No
#
#            TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
churn_df.tail()
# Out:
#      Unnamed: 0 Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 995        3995   Yes    Male              0      No        Yes      28
# 996        3996    No    Male              0      No         No      24
# 997        3997    No  Female              0     Yes         No      69
# 998        3998    No    Male              0     Yes        Yes      42
# 999        3999   Yes  Female              1      No         No       2
#
#     PhoneService MultipleLines InternetService  ...     DeviceProtection  \
# 995          Yes            No     Fiber optic  ...                   No
# 996          Yes            No              No  ...  No internet service
# 997          Yes            No             DSL  ...                   No
# 998          Yes            No             DSL  ...                   No
# 999          Yes            No     Fiber optic  ...                   No
#
#              TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
churn_df.describe()
# Out:
#         Unnamed: 0  SeniorCitizen      tenure  MonthlyCharges  TotalCharges  \
# count  1000.000000    1000.000000  1000.00000     1000.000000   1000.000000
# mean   3499.500000       0.158000    30.50300       63.761950   2157.514300
# std     288.819436       0.364924    24.36127       29.909968   2237.636786
# min    3000.000000       0.000000     0.00000       18.250000     19.100000
# 25%    3249.750000       0.000000     8.00000       34.587500    313.487500
# 50%    3499.500000       0.000000    26.00000       69.800000   1286.025000
# 75%    3749.250000       0.000000    52.00000       88.812500   3489.062500
# max    3999.000000       1.000000    72.00000      118.600000   8425.150000
#
#         customerID
# count  1000.000000
# mean   3500.500000
# std     288.819436
# min    3001.000000
# 25%    3250.750000
# 50%    3500.500000
# 75%    3750.250000
# max    4000.000000

# %% [markdown]
# Not all columns start with a Capital letter, for unity when indexing, I will capitalise the first letter of each variable

# %%
churn_df.columns
# Out:
# Index(['Unnamed: 0', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'customerID'],
#       dtype='object')

# %%
churn_df.columns = churn_df.columns.str.capitalize()

# %%
churn_df.dtypes
# Out:
# Unnamed: 0            int64
# Churn                object
# Gender               object
# Seniorcitizen         int64
# Partner              object
# Dependents           object
# Tenure                int64
# Phoneservice         object
# Multiplelines        object
# Internetservice      object
# Onlinesecurity       object
# Onlinebackup         object
# Deviceprotection     object
# Techsupport          object
# Streamingtv          object
# Streamingmovies      object
# Contract             object
# Paperlessbilling     object
# Paymentmethod        object
# Monthlycharges      float64
# Totalcharges        float64
# Customerid            int64
# dtype: object

# %%
churn_df.shape
# Out:
# (1000, 22)

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Churn             1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Seniorcitizen     1000 non-null   int64
#  4   Partner           1000 non-null   object
#  5   Dependents        1000 non-null   object
#  6   Tenure            1000 non-null   int64
#  7   Phoneservice      1000 non-null   object
#  8   Multiplelines     1000 non-null   object
#  9   Internetservice   1000 non-null   object
#  10  Onlinesecurity    1000 non-null   object
#  11  Onlinebackup      1000 non-null   object
#  12  Deviceprotection  1000 non-null   object
#  13  Techsupport       1000 non-null   object
#  14  Streamingtv       1000 non-null   object
#  15  Streamingmovies   1000 non-null   object
# ...

# %%
print(churn_df['Churn'].value_counts().to_string())
# Out:
# Churn
# No     723
# Yes    277

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Churn", data=churn_df, palette="Set1")
plt.title("Customer Churn Distribution", fontsize=14, fontweight='bold')
plt.ylabel("Count")
plt.xlabel("Churn Status")
plt.tight_layout()
plt.show()

# Clean percentage output
print("Churn Rate:")
print(churn_df["Churn"].value_counts(normalize=True).round(3) * 100)
# Out:
# Churn Rate:
# Churn
# No     72.3
# Yes    27.7
# Name: proportion, dtype: float64
